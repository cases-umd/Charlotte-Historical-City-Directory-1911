# %% [markdown]
# ### Introductory Sheets: Race, Spouse, Job
#
# Here we will look at three different graphs mapping out Race, Spouse, and Job each independently. We should from this be able to grasp each of their relative relations to the entire data-set.
#
# **Race**
# ![Screenshot Race.png](attachment:e2caccf2-5bd7-4903-b1c5-04bbdb757c2f.png)
#
# **Spouse**
# ![Screenshot Spouse.png](attachment:3e8b6f71-fd20-40c7-b444-ecd27743289c.png)
#
# **Job**
# ![Screenshot Job.png](attachment:23d8dab2-0e29-4816-bad4-c5dd75e8d20b.png)

# %% [markdown]
# From here we can make some basic caculations to help quantify the data and put it into perspective.
#
# Race:
# <le>
#     <ul>11117/15710=0.7076x100=**71%** of the data-set are marked as White</ul>
#     <ul>So if 71% of the total data-set is catigorized as White then the remaining **23%** of the data-set is marked as Black</ul>
# </le>
# Spouse
# <le>
#     <ul>We may do the same caculations for those with Spouses</ul>
#     <ul>5869/15710=0.3735x100=**37%** have spouses</ul>
#     <ul>So in turn, **63% of data-points to not have spouses**</ul>
# </le>
# Job
# <le>
#     <ul>One last time then, 11697/15710=0.7446x100=**75%** of data-points have Jobs</ul>
#     <ul>and so, **25%** do not have Jobs</ul>

# %% [markdown]
# Next: [CombinedDataSheets](CombinedDataSheets.ipynb)
